# %% [markdown]
# ## Install the Ultralytics

# %%
# !pip install ultralytics
# Out:
# ...
# ^C
# ERROR: Operation cancelled by user

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.7 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5359.4/8062.4 GB disk)

# %% [markdown]
# ## Importing necessary modules for YOLO

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## Execute YOLO training task

# %%
# !yolo task=detect mode=train model=yolov8s.pt data = '/kaggle/input/websitescreenshots/data.yaml' epochs=20 imgsz=224 plots=True
# Out:
# ...
# 100%|███████████████████████████████████████| 21.5M/21.5M [00:00<00:00, 204MB/s]
# Ultralytics YOLOv8.1.7 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...

# %% [markdown]
# - The following command is used to make predictions using a trained YOLO model on a set of input images.
# - This task involves applying the trained model to new data to identify and locate objects in those images.

# %%
# !yolo task=detect mode=predict model= "/kaggle/working/runs/detect/train/weights/best.pt" conf=0.25 source= "/kaggle/input/testing/*"
# Out:
# Ultralytics YOLOv8.1.7 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# Model summary (fused): 168 layers, 11128680 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/4 /kaggle/input/testing/Menu.png: 224x128 3 buttons, 1 field, 1 heading, 6 images, 1 text, 54.2ms
# image 2/4 /kaggle/input/testing/Sign In Page.png: 224x128 2 buttons, 6 fields, 2 images, 6.5ms
# image 3/4 /kaggle/input/testing/Sign Up Page.png: 224x128 2 buttons, 6 fields, 2 images, 6.3ms
# image 4/4 /kaggle/input/testing/Splash Screen.png: 224x128 1 heading, 6.2ms
# Speed: 1.2ms preprocess, 18.3ms inference, 31.4ms postprocess per image at shape (1, 3, 224, 128)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Import necessary modules for file handling and image display in Jupyter Notebook.
import glob
from IPython.display import Image, display

# Iterate over the first 10 image paths in the specified directory.
# The glob.glob function is used to retrieve a list of file paths matching the specified pattern.
for image_path in glob.glob('/kaggle/working/runs/detect/predict2/*')[:10]:
    
    # Display each image using the IPython Image module with a width of 600 pixels.
    display(Image(filename=image_path, width=600))
    
    # Print a newline for better separation between displayed images.
    print("\n")
